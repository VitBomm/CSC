# %%
import numpy as np
import pandas as pd

# %%
employees = pd.read_excel('employees.xls')

# %%
employees.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  \
# 0          100     Steven      King     SKING  515.123.4567
# 1          101      Neena   Kochhar  NKOCHHAR  515.123.4568
# 2          102        Lex   De Haan   LDEHAAN  515.123.4569
# 3          103  Alexander    Hunold   AHUNOLD  590.423.4567
# 4          104      Bruce     Ernst    BERNST  590.423.4568
#
#              HIRE_DATE   JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  \
# 0  2003-06-17 00:00:00  AD_PRES   24000             NaN         NaN
# 1  2005-09-21 00:00:00    AD_VP   17000             NaN       100.0
# 2  2001-01-13 00:00:00    AD_VP   17000             NaN       100.0
# 3  2006-01-03 00:00:00  IT_PROG    9000             NaN       102.0
# 4  2007-05-21 00:00:00  IT_PROG    6000             NaN       103.0
#
#    DEPARTMENT_ID
# 0           90.0
# 1           90.0
# 2           90.0
# 3           60.0
# 4           60.0

# %%
employees.shape
# Out:
# (107, 11)

# %%
employees[employees.DEPARTMENT_ID.isnull()]
# Out:
#     EMPLOYEE_ID FIRST_NAME LAST_NAME   EMAIL        PHONE_NUMBER  \
# 78          178  Kimberely     Grant  KGRANT  011.44.1644.429263
#
#               HIRE_DATE  JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  \
# 78  2007-05-24 00:00:00  SA_REP    7000            0.15       149.0
#
#     DEPARTMENT_ID
# 78            NaN

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 11 columns):
# EMPLOYEE_ID       107 non-null int64
# FIRST_NAME        107 non-null object
# LAST_NAME         107 non-null object
# EMAIL             107 non-null object
# PHONE_NUMBER      107 non-null object
# HIRE_DATE         107 non-null object
# JOB_ID            107 non-null object
# SALARY            107 non-null int64
# COMMISSION_PCT    35 non-null float64
# MANAGER_ID        106 non-null float64
# DEPARTMENT_ID     106 non-null float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 9.3+ KB

# %%
# ve bar plot de bieu dien tong luong cua moi phong
data = employees.groupby('DEPARTMENT_ID').SALARY.sum()

# %%
data
# Out:
# DEPARTMENT_ID
# 10.0       4400
# 20.0      19000
# 30.0      24900
# 40.0       6500
# 50.0     156400
# 60.0      28800
# 70.0      10000
# 80.0     304500
# 90.0      58000
# 100.0     51608
# 110.0     20308
# Name: SALARY, dtype: int64

# %%
type(data)
# Out:
# pandas.core.series.Series

# %%
data.plot.bar()

# %%
data.plot.barh()

# %%
employees.DEPARTMENT_ID.value_counts()
# Out:
# 50.0     45
# 80.0     34
# 30.0      6
# 100.0     6
# 60.0      5
# 90.0      3
# 110.0     2
# 20.0      2
# 70.0      1
# 40.0      1
# 10.0      1
# Name: DEPARTMENT_ID, dtype: int64

# %%
employees.DEPARTMENT_ID.value_counts().plot.bar()

# %%
# ve box plot luong tat ca nhan vien
employees['SALARY'].plot.box()

# %%
employees['SALARY'].describe()
# Out:
# count      107.000000
# mean      6461.831776
# std       3909.579731
# min       2100.000000
# 25%       3100.000000
# 50%       6200.000000
# 75%       8900.000000
# max      24000.000000
# Name: SALARY, dtype: float64

# %%
IQR = 8900-3100
m = 8900+1.5*IQR
m
# Out:
# 17600.0

# %%
test_data = np.array([30,30,32,33,35,38,40,41,41,45])
test_data
# Out:
# array([30, 30, 32, 33, 35, 38, 40, 41, 41, 45])

# %%
data = pd.DataFrame(test_data)
data
# Out:
#     0
# 0  30
# 1  30
# 2  32
# 3  33
# 4  35
# 5  38
# 6  40
# 7  41
# 8  41
# 9  45

# %%
data.describe()
# Out:
#                0
# count  10.000000
# mean   36.500000
# std     5.233439
# min    30.000000
# 25%    32.250000
# 50%    36.500000
# 75%    40.750000
# max    45.000000

# %%
data
# Out:
#     0
# 0  30
# 1  30
# 2  32
# 3  33
# 4  35
# 5  38
# 6  40
# 7  41
# 8  41
# 9  45

# %%
data.quantile(0.25)
# Out:
# 0    32.25
# Name: 0.25, dtype: float64

# %%
data = pd.Series([10,12,12,12,14,14,15,20,20,20,23,25])
data
# Out:
# 0     10
# 1     12
# 2     12
# 3     12
# 4     14
# 5     14
# 6     15
# 7     20
# 8     20
# 9     20
# 10    23
# 11    25
# dtype: int64

# %%
data.plot.hist()

# %%
data = employees.groupby('DEPARTMENT_ID').SALARY.sum()

# %%
data
# Out:
# DEPARTMENT_ID
# 10.0       4400
# 20.0      19000
# 30.0      24900
# 40.0       6500
# 50.0     156400
# 60.0      28800
# 70.0      10000
# 80.0     304500
# 90.0      58000
# 100.0     51608
# 110.0     20308
# Name: SALARY, dtype: int64

# %%
data.plot()

# %%
data.plot(kind='line')

# %%
data.plot(kind='bar')

# %%
# ve histogram cua cac chieu cao
heights = pd.Series([74, 74, 72, 72, 73, 69, 69, 71, 76, 71, 73, 73, 74, 74, 69, 70, 73, 75, 78, 79, 76, 74, 76, 72, 71, 75, 77, 74, 73, 74, 78, 73, 75, 73, 75, 75, 74, 69, 71, 74, 73, 73, 76, 74, 74, 70, 72, 77, 74, 70, 73, 75, 76, 76, 78, 74, 74, 76, 77, 81, 78, 75, 77, 75, 76, 74, 72, 72, 75, 73,  73, 73, 70, 70, 70, 76, 68, 71, 72, 75, 75, 75, 75, 68, 74, 78, 71, 73, 76, 74, 74, 79, 75, 73, 76, 74, 74, 73, 72, 74, 73, 74, 72, 73, 69, 72, 73, 75, 75, 73, 72, 72, 76, 74, 72, 77, 74, 77, 75, 76, 80, 74, 74, 75, 78, 73, 73, 74, 75, 76, 71, 73, 74, 76, 76, 74, 73, 74, 70, 72,  73, 73, 73, 73, 71, 74, 74, 72, 74, 71, 74, 73, 75, 75, 79, 73, 75, 76, 74, 76, 78, 74, 76, 72, 74, 76, 74, 75, 78, 75, 72, 74, 72, 74, 70, 71, 70, 75, 71, 71, 73, 72, 71, 73, 72, 75, 74, 74, 75, 73, 77, 73, 76, 75, 74, 76, 75, 73, 71, 76, 75, 72, 71, 77, 73, 74, 71, 72, 74, 75,    73, 72, 75, 75, 74, 72, 74, 71, 70, 74, 77, 77, 75, 75, 78, 75, 76, 73, 75, 75, 79, 77, 76, 71, 75, 74, 69, 71, 76, 72, 72, 70, 72, 73, 71, 72, 71, 73, 72, 73, 74, 74, 72, 75, 74, 74, 77, 75, 73, 72, 71, 74, 77, 75, 75, 75, 78, 78, 74, 76, 78, 76, 70, 72, 80, 74, 74, 71, 70, 72,    71, 74, 71, 72, 71, 74, 69, 76, 75, 75, 76, 73, 76, 73, 77, 73, 72, 72, 77, 77, 71, 74, 74, 73, 78, 75, 73, 70, 74, 72, 73, 73, 75, 75, 74, 76, 73, 74, 75, 75, 72, 73, 73, 72, 74, 78, 76, 73, 74, 75, 70, 75, 71, 72, 78, 75, 73, 73, 71, 75, 77, 72, 69, 73, 74, 72, 70, 75, 70, 72,    72, 74, 73, 74, 76, 75, 80, 72, 75, 73, 74, 74, 73, 75, 75, 71, 73, 75, 74, 74, 72, 74, 74, 74, 73, 76, 75, 72, 73, 73, 73, 72, 72, 72, 72, 71, 75, 75, 74, 73, 75, 79, 74, 76, 73, 74, 74, 72, 74, 74, 75, 78, 74, 74, 74, 77, 70, 73, 74, 73, 71, 75, 71, 72, 77, 74, 70, 77, 73, 72, 76, 71, 76, 78, 75, 73, 78, 74, 79, 75, 76, 72, 75, 75, 70, 72, 70, 74, 71, 76, 73, 76, 71, 69, 72, 72, 69, 73, 69, 73, 74, 74, 72, 71, 72, 72, 76, 76, 76, 74, 76, 75, 71, 72, 71, 73, 75, 76, 75, 71, 75, 74, 72, 73, 73, 73, 73, 76, 72, 76, 73, 73, 73, 75, 75, 77, 73, 72, 75, 70, 74, 72, 80, 71, 71, 74, 74, 73, 75, 76, 73, 77, 72, 73, 77, 76, 71, 75, 73, 74, 77, 71, 72, 73, 69, 73, 70, 74, 76, 73, 73, 75, 73, 79, 74, 73, 74, 77, 75, 74, 73, 77, 73, 77, 74, 74, 73, 77, 74, 77, 75, 77, 75, 71, 74, 70, 79, 72, 72, 70, 74, 74, 72, 73, 72, 74, 74, 76, 82, 74, 74, 70, 73, 73, 74, 77, 72, 76, 73, 73, 72, 74, 74, 71, 72, 75, 74, 74, 77, 70, 71, 73, 76, 71, 75, 74, 72, 76, 79, 76, 73, 76, 78, 75, 76, 72, 72, 73, 73, 75, 71, 76, 70, 75, 74, 75, 73, 71, 71, 72, 73, 73, 72, 69, 73, 78, 71, 73, 75, 76, 70, 74, 77, 75, 79, 72, 77, 73, 75, 75, 75, 73, 73, 76, 77, 75, 70, 71, 71, 75, 74, 69, 70, 75, 72, 75, 73, 72, 72, 72, 76, 75, 74, 69, 73, 72, 72, 75, 77, 76, 80, 77, 76, 79, 71, 75, 73, 76, 77, 73, 76, 70, 75, 73, 75, 70, 69, 71, 72, 72, 73, 70, 70, 73, 76, 75, 72, 73, 79, 71, 72, 74, 74, 74, 72, 76, 76, 72, 72, 71, 72, 72, 70, 77, 74, 72, 76, 71, 76, 71, 73, 70, 73, 73, 72, 71, 71, 71, 72, 72, 74, 74, 74, 71, 72, 75, 72, 71, 72, 72, 72, 72, 74, 74, 77, 75, 73, 75, 73, 76, 72, 77, 75, 72, 71, 71, 75, 72, 73, 73, 71, 70, 75, 71, 76, 73, 68, 71, 72, 74, 77, 72, 76, 78, 81, 72, 73, 76, 72, 72, 74, 76, 73, 76, 75, 70, 71, 74, 72, 73, 76, 76, 73, 71, 68, 71, 71, 74, 77, 69, 72, 76, 75, 76, 75, 76, 72, 74, 76, 74, 72, 75, 78, 77, 70, 72, 79, 74, 71, 68, 77, 75, 71, 72, 70, 72, 72, 73, 72, 74, 72, 72, 75, 72, 73, 74, 72, 78, 75, 72, 74, 75, 75, 76, 74, 74, 73, 74, 71, 74, 75, 76, 74, 76, 76, 73, 75, 75, 74, 68, 72, 75, 71, 70, 72, 73, 72, 75, 74, 70, 76, 71, 82, 72, 73, 74, 71, 75, 77, 72, 74, 72, 73, 78, 77, 73, 73, 73, 73, 73, 76, 75, 70, 73, 72, 73, 75, 74, 73, 73, 76, 73, 75, 70, 77, 72, 77, 74, 75, 75, 75, 75, 72, 74, 71, 76, 71, 75, 76, 83, 75, 74, 76, 72, 72, 75, 75, 72, 77, 73, 72, 70, 74, 72, 74, 72, 71, 70, 71, 76, 74, 76, 74, 74, 74, 75, 75, 71, 71, 74, 77, 71, 74, 75, 77, 76, 74, 76, 72, 71, 72, 75, 73, 68, 72, 69, 73, 73, 75, 70, 70, 74, 75, 74, 74, 73, 74, 75, 77, 73, 74, 76, 74, 75, 73, 76, 78, 75, 73, 77, 74, 72, 74, 72, 71, 73, 75, 73, 67, 67, 76, 74, 73, 70, 75, 70, 72, 77, 79, 78, 74, 75, 75, 78, 76, 75, 69, 75, 72, 75, 73, 74, 75, 75, 73])

# %%
heights.head()
# Out:
# 0    74
# 1    74
# 2    72
# 3    72
# 4    73
# dtype: int64

# %%
heights.plot.hist()

# %%
heights.plot.kde()

# %%
heights.mean()
# Out:
# 73.6896551724138

# %%
heights.median()
# Out:
# 74.0

# %%
heights.plot.box()

# %%
employees
# Out:
#      EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  \
# 0            100     Steven      King     SKING  515.123.4567
# 1            101      Neena   Kochhar  NKOCHHAR  515.123.4568
# 2            102        Lex   De Haan   LDEHAAN  515.123.4569
# 3            103  Alexander    Hunold   AHUNOLD  590.423.4567
# 4            104      Bruce     Ernst    BERNST  590.423.4568
# ..           ...        ...       ...       ...           ...
# 102          202        Pat       Fay      PFAY  603.123.6666
# 103          203      Susan    Mavris   SMAVRIS  515.123.7777
# 104          204    Hermann      Baer     HBAER  515.123.8888
# 105          205    Shelley   Higgins  SHIGGINS  515.123.8080
# 106          206    William     Gietz    WGIETZ  515.123.8181
#
#                HIRE_DATE      JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  \
# 0    2003-06-17 00:00:00     AD_PRES   24000             NaN         NaN
# ...

# %%
employees[['EMPLOYEE_ID','FIRST_NAME','SALARY']] # feature
# Out:
#      EMPLOYEE_ID FIRST_NAME  SALARY
# 0            100     Steven   24000
# 1            101      Neena   17000
# 2            102        Lex   17000
# 3            103  Alexander    9000
# 4            104      Bruce    6000
# ..           ...        ...     ...
# 102          202        Pat    6000
# 103          203      Susan    6500
# 104          204    Hermann   10000
# 105          205    Shelley   12008
# 106          206    William    8300
#
# [107 rows x 3 columns]

# %%
employees[(employees['SALARY']>=5000) & (employees['SALARY']<=7000)] #filter
# Out:
#      EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL        PHONE_NUMBER  \
# 4            104      Bruce     Ernst    BERNST        590.423.4568
# 13           113       Luis      Popp     LPOPP        515.124.4567
# 23           123     Shanta   Vollman  SVOLLMAN        650.123.4234
# 24           124      Kevin   Mourgos  KMOURGOS        650.123.5234
# 55           155     Oliver   Tuvault  OTUVAULT  011.44.1344.486508
# 61           161     Sarath    Sewall   SSEWALL  011.44.1345.529268
# 65           165      David       Lee      DLEE  011.44.1346.529268
# 66           166     Sundar      Ande     SANDE  011.44.1346.629268
# 67           167       Amit     Banda    ABANDA  011.44.1346.729268
# 73           173    Sundita     Kumar    SKUMAR  011.44.1343.329268
# 78           178  Kimberely     Grant    KGRANT  011.44.1644.429263
# 79           179    Charles   Johnson  CJOHNSON  011.44.1644.429262
# 102          202        Pat       Fay      PFAY        603.123.6666
# ...

# %%
data = employees[(employees['SALARY']>=5000) & (employees['SALARY']<=7000)] #extract

# %%
data
# Out:
#      EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL        PHONE_NUMBER  \
# 4            104      Bruce     Ernst    BERNST        590.423.4568
# 13           113       Luis      Popp     LPOPP        515.124.4567
# 23           123     Shanta   Vollman  SVOLLMAN        650.123.4234
# 24           124      Kevin   Mourgos  KMOURGOS        650.123.5234
# 55           155     Oliver   Tuvault  OTUVAULT  011.44.1344.486508
# 61           161     Sarath    Sewall   SSEWALL  011.44.1345.529268
# 65           165      David       Lee      DLEE  011.44.1346.529268
# 66           166     Sundar      Ande     SANDE  011.44.1346.629268
# 67           167       Amit     Banda    ABANDA  011.44.1346.729268
# 73           173    Sundita     Kumar    SKUMAR  011.44.1343.329268
# 78           178  Kimberely     Grant    KGRANT  011.44.1644.429263
# 79           179    Charles   Johnson  CJOHNSON  011.44.1644.429262
# 102          202        Pat       Fay      PFAY        603.123.6666
# ...

# %%
data = employees[(employees['SALARY']>=5000) & (employees['SALARY']<=7000)][['EMPLOYEE_ID','FIRST_NAME','SALARY']] #extract

# %%
data
# Out:
#      EMPLOYEE_ID FIRST_NAME  SALARY
# 4            104      Bruce    6000
# 13           113       Luis    6900
# 23           123     Shanta    6500
# 24           124      Kevin    5800
# 55           155     Oliver    7000
# 61           161     Sarath    7000
# 65           165      David    6800
# 66           166     Sundar    6400
# 67           167       Amit    6200
# 73           173    Sundita    6100
# 78           178  Kimberely    7000
# 79           179    Charles    6200
# 102          202        Pat    6000
# 103          203      Susan    6500

# %%
data['BONUS'] = data['SALARY'] + 300

# %%
data
# Out:
#      EMPLOYEE_ID FIRST_NAME  SALARY  BONUS
# 4            104      Bruce    6000   6300
# 13           113       Luis    6900   7200
# 23           123     Shanta    6500   6800
# 24           124      Kevin    5800   6100
# 55           155     Oliver    7000   7300
# 61           161     Sarath    7000   7300
# 65           165      David    6800   7100
# 66           166     Sundar    6400   6700
# 67           167       Amit    6200   6500
# 73           173    Sundita    6100   6400
# 78           178  Kimberely    7000   7300
# 79           179    Charles    6200   6500
# 102          202        Pat    6000   6300
# 103          203      Susan    6500   6800

# %%
# tao cot loai luong: 'GOOD' neu nhu salary>=10000, 'IMMEDATE' neu nhu salary<10000
data['TYPE'] = np.where(data['SALARY']>=10000, 'GOOD','IMMEDATE')

# %%
data.reset_index(inplace=True, drop=True)

# %%
data
# Out:
#     EMPLOYEE_ID FIRST_NAME  SALARY  BONUS      TYPE
# 0           104      Bruce    6000   6300  IMMEDATE
# 1           113       Luis    6900   7200  IMMEDATE
# 2           123     Shanta    6500   6800  IMMEDATE
# 3           124      Kevin    5800   6100  IMMEDATE
# 4           155     Oliver    7000   7300  IMMEDATE
# 5           161     Sarath    7000   7300  IMMEDATE
# 6           165      David    6800   7100  IMMEDATE
# 7           166     Sundar    6400   6700  IMMEDATE
# 8           167       Amit    6200   6500  IMMEDATE
# 9           173    Sundita    6100   6400  IMMEDATE
# 10          178  Kimberely    7000   7300  IMMEDATE
# 11          179    Charles    6200   6500  IMMEDATE
# 12          202        Pat    6000   6300  IMMEDATE
# 13          203      Susan    6500   6800  IMMEDATE

# %%
data.loc[data.shape[0]] = [300,'ABC',13000,13000+500,'GOOD']

# %%
data
# Out:
#     EMPLOYEE_ID FIRST_NAME  SALARY  BONUS      TYPE
# 0           104      Bruce    6000   6300  IMMEDATE
# 1           113       Luis    6900   7200  IMMEDATE
# 2           123     Shanta    6500   6800  IMMEDATE
# 3           124      Kevin    5800   6100  IMMEDATE
# 4           155     Oliver    7000   7300  IMMEDATE
# 5           161     Sarath    7000   7300  IMMEDATE
# 6           165      David    6800   7100  IMMEDATE
# 7           166     Sundar    6400   6700  IMMEDATE
# 8           167       Amit    6200   6500  IMMEDATE
# 9           173    Sundita    6100   6400  IMMEDATE
# 10          178  Kimberely    7000   7300  IMMEDATE
# 11          179    Charles    6200   6500  IMMEDATE
# 12          202        Pat    6000   6300  IMMEDATE
# 13          203      Susan    6500   6800  IMMEDATE
# 14          300        ABC   13000  13500      GOOD

# %%
data = data.append({'EMPLOYEE_ID':301,'FIRST_NAME':'XYZ','SALARY':13000},ignore_index=True)

# %%
data
# Out:
#     EMPLOYEE_ID FIRST_NAME  SALARY    BONUS      TYPE
# 0           104      Bruce    6000   6300.0  IMMEDATE
# 1           113       Luis    6900   7200.0  IMMEDATE
# 2           123     Shanta    6500   6800.0  IMMEDATE
# 3           124      Kevin    5800   6100.0  IMMEDATE
# 4           155     Oliver    7000   7300.0  IMMEDATE
# 5           161     Sarath    7000   7300.0  IMMEDATE
# 6           165      David    6800   7100.0  IMMEDATE
# 7           166     Sundar    6400   6700.0  IMMEDATE
# 8           167       Amit    6200   6500.0  IMMEDATE
# 9           173    Sundita    6100   6400.0  IMMEDATE
# 10          178  Kimberely    7000   7300.0  IMMEDATE
# 11          179    Charles    6200   6500.0  IMMEDATE
# 12          202        Pat    6000   6300.0  IMMEDATE
# 13          203      Susan    6500   6800.0  IMMEDATE
# 14          300        ABC   13000  13500.0      GOOD
# 15          301        XYZ   13000      NaN       NaN

# %%
employees.groupby('JOB_ID')['SALARY'].mean()
# Out:
# JOB_ID
# AC_ACCOUNT     8300
# AC_MGR        12008
# AD_ASST        4400
# AD_PRES       24000
# AD_VP         17000
# FI_ACCOUNT     7920
# FI_MGR        12008
# HR_REP         6500
# IT_PROG        5760
# MK_MAN        13000
# MK_REP         6000
# PR_REP        10000
# PU_CLERK       2780
# PU_MAN        11000
# SA_MAN        12200
# SA_REP         8350
# SH_CLERK       3215
# ST_CLERK       2785
# ST_MAN         7280
# Name: SALARY, dtype: int64

# %%
employees['BONUS'] = employees['SALARY']*12

# %%
data = employees.groupby('JOB_ID', as_index=False)[['SALARY','BONUS']].mean()

# %%
data
# Out:
#         JOB_ID  SALARY   BONUS
# 0   AC_ACCOUNT    8300   99600
# 1       AC_MGR   12008  144096
# 2      AD_ASST    4400   52800
# 3      AD_PRES   24000  288000
# 4        AD_VP   17000  204000
# 5   FI_ACCOUNT    7920   95040
# 6       FI_MGR   12008  144096
# 7       HR_REP    6500   78000
# 8      IT_PROG    5760   69120
# 9       MK_MAN   13000  156000
# 10      MK_REP    6000   72000
# 11      PR_REP   10000  120000
# 12    PU_CLERK    2780   33360
# 13      PU_MAN   11000  132000
# 14      SA_MAN   12200  146400
# 15      SA_REP    8350  100200
# 16    SH_CLERK    3215   38580
# 17    ST_CLERK    2785   33420
# 18      ST_MAN    7280   87360
