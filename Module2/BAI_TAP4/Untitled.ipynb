# %%
import numpy as np
import pandas as pd
data_cn = pd.read_csv('sinh_vien_CN.csv')
data_to = pd.read_csv('sinh_vien_VL.csv')
data_ly = pd.read_csv('sinh_vien_TO.csv')

# %%
data = pd.concat([data_cn,data_to,data_ly])

# %%
data.reset_index(drop=True,inplace=True)

# %%
data
# Out:
#       masv              ho    ten  gioitinh             ngaysinh  \
# 0    C0001     Khương Thảo   Loan     False  1999-01-04 00:00:00
# 1    C0002       Đặng Bạch   Ngọc      True  1999-11-11 00:00:00
# 2    C0003   Phạm Văn Minh  Thiện      True  1999-11-23 00:00:00
# 3    C0004  Đinh Thị Thanh   Dung     False  1999-01-19 00:00:00
# 4    C0005       Trần Mạnh  Thiện      True  1999-08-19 00:00:00
# ..     ...             ...    ...       ...                  ...
# 995  T0596        Đinh Nam    Bảo      True  1999-05-15 00:00:00
# 996  T0597        Đàm Minh   Ngân     False  1999-02-03 00:00:00
# 997  T0598     Lý Thị Thảo   Loan     False  1999-05-29 00:00:00
# 998  T0599      Hoàng Vĩnh  Phong      True  1999-07-09 00:00:00
# 999  T0600       Đinh Vĩnh    Lộc      True  1999-11-22 00:00:00
#
#                   email     didong          cmnd  hocbong makh
# 0      ktloan@gmail.com  987314518  586900775484  2000000   CN
# ...
