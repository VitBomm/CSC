# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
service_district = gpd.read_file('data/school_districts.geojson.txt') # geodataframe
service_district.head()
# Out:
#    first_name       city    zip                           email state  \
# 0  Dr. Sharon  Nashville  37218  gentryfordistrict1@comcast.net    TN
# 1        Jill    Madison  37115          jill.speering@mnps.org    TN
# 2  Dr. Jo Ann  Nashville  37220          joann.brannon@mnps.org    TN
# 3        Anna  Hermitage  37076          anna.shepherd@mnps.org    TN
# 4         Amy  Nashville  37221             amy.frogge@mnps.org    TN
#
#   last_name                address    position term_expir district  \
# 0    Gentry        6108 Beals Lane      Member       2016        1
# 1  Speering      1033 Falls Avenue  Vice-Chair       2016        3
# 2   Brannon  5444 San Marcos Drive      Member       2018        2
# 3  Shepherd     4545 Raccoon Trail       Chair       2018        4
# 4    Frogge  7237 Riverfront Drive      Member       2016        9
#
#           phone                                           geometry
# 0  615-268-5269  (POLYGON ((-86.77136400034288 36.3835669997190...
# ...

# %%
type(service_district)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
service_district.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 12 columns):
# first_name    9 non-null object
# city          9 non-null object
# zip           9 non-null object
# email         9 non-null object
# state         9 non-null object
# last_name     9 non-null object
# address       9 non-null object
# position      9 non-null object
# term_expir    9 non-null object
# district      9 non-null object
# phone         9 non-null object
# geometry      9 non-null object
# dtypes: object(12)
# memory usage: 992.0+ bytes

# %%
service_district.iloc[0]
# Out:
# id                                                       3850184
# name                                                Saigon South
# localname                                 Khu đô thị Nam Sài Gòn
# timestamp                                    2016-03-18T23:05:02
# SRID                                                        4326
# admin_level                                                    5
# tags           {'name': 'Khu đô thị Nam Sài Gòn', 'name:en': ...
# geometry       (POLYGON ((106.6934435 10.7221295, 106.694747 ...
# Name: 0, dtype: object

# %%
service_district.loc[0,'geometry']

# %%
service_district.loc[1,'geometry']

# %%
service_district.plot(column='district',figsize=(8,8), legend=True)

# %%
service_district = gpd.read_file('data/district-boundary-hcm-city.geojson')
service_district.head()
# Out:
#         id                 name               localname            timestamp  \
# 0  3850184         Saigon South  Khu đô thị Nam Sài Gòn  2016-03-18T23:05:02
# 1  3797166  Binh Thanh District         Quận Bình Thạnh  2016-03-18T23:05:02
# 2  2587287           District 1                  Quận 1  2016-03-18T23:05:02
# 3  3819816           District 3                  Quận 3  2016-03-18T23:05:02
# 4  2778323           District 4                  Quận 4  2016-03-18T23:05:02
#
#    SRID  admin_level                                               tags  \
# 0  4326            5  {'name': 'Khu đô thị Nam Sài Gòn', 'name:en': ...
# 1  4326            6  {'name': 'Quận Bình Thạnh', 'name:en': 'Binh T...
# 2  4326            6  {'name': 'Quận 1', 'name:en': 'District 1', 'n...
# 3  4326            6  {'name': 'Quận 3', 'name:en': 'District 3', 'n...
# 4  4326            6  {'name': 'Quận 4', 'name:en': 'District 4', 'b...
#
#                                             geometry
# ...

# %%
service_district.plot(column = 'name', cmap = 'Set2', figsize=(16,12), legend=True)
