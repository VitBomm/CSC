# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
museum_data = pd.read_csv('museum_visitors.csv', index_col="Date", parse_dates=True)

# %%
museum_data.shape
# Out:
# (59, 4)

# %%
museum_data.head()
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2014-01-01        24778              4486                     1581
# 2014-01-02        18976              4172                     1785
# 2014-01-03        25231              7082                     3229
# 2014-01-04        26989              6756                     2129
# 2014-01-05        36883             10858                     3676
#
#             America Tropical Interpretive Center
# Date
# 2014-01-01                                  6602
# 2014-01-02                                  5029
# 2014-01-03                                  8129
# 2014-01-04                                  2824
# 2014-01-05                                 10694

# %%
museum_data.tail()
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2018-01-07        23136              4191                     2620
# 2018-01-08        20815              4866                     2409
# 2018-01-09        21020              4956                     2146
# 2018-01-10        19280              4622                     2364
# 2018-01-11        17163              4082                     2385
#
#             America Tropical Interpretive Center
# Date
# 2018-01-07                                  4718
# 2018-01-08                                  3891
# 2018-01-09                                  3180
# 2018-01-10                                  3775
# 2018-01-11                                  4562

# %%
plt.figure(figsize=(14,6))
sns.lineplot(data=museum_data)

# %%
plt.figure(figsize=(14,6))
sns.lineplot(data=museum_data['Avila Adobe'], label="Avila Adobe")
plt.xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')
