# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
spotify_data = pd.read_csv('spotify.csv', index_col="Date", parse_dates=True)

# %%
spotify_data.shape
# Out:
# (366, 5)

# %%
spotify_data.head(10)
# Out:
#             Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# Date
# 2017-06-01      12287078        NaN                       NaN      NaN
# 2017-07-01      13190270        NaN                       NaN      NaN
# 2017-08-01      13099919        NaN                       NaN      NaN
# 2017-09-01      14506351        NaN                       NaN      NaN
# 2017-10-01      14275628        NaN                       NaN      NaN
# 2017-11-01      14372699        NaN                       NaN      NaN
# 2017-12-01      14148108        NaN                       NaN      NaN
# 2017-01-13      14536236   275178.0                       NaN      NaN
# 2017-01-14      14173311  1144886.0                       NaN      NaN
# 2017-01-15      12889849  1288198.0                       NaN      NaN
#
#             Unforgettable
# Date
# 2017-06-01            NaN
# 2017-07-01            NaN
# 2017-08-01            NaN
# 2017-09-01            NaN
# 2017-10-01            NaN
# 2017-11-01            NaN
# 2017-12-01            NaN
# 2017-01-13            NaN
# 2017-01-14            NaN
# 2017-01-15            NaN

# %%
spotify_data.tail(10)
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2017-12-31       7073032  8203454.0                 3514602.0  2787752.0
# 2018-01-01       4865387  5557165.0                 2179506.0  2368321.0
# 2018-02-01       4541816  3980200.0                 2368870.0  2505241.0
# 2018-03-01       4596993  3890385.0                 2363422.0  2587620.0
# 2018-04-01       4447076  3512667.0                 2345804.0  2575748.0
# 2018-05-01       4492978  3450315.0                 2408365.0  2685857.0
# 2018-06-01       4416476  3394284.0                 2188035.0  2559044.0
# 2018-07-01       4009104  3020789.0                 1908129.0  2350985.0
# 2018-08-01       4135505  2755266.0                 2023251.0  2523265.0
# 2018-09-01       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2017-12-31      3792953.0
# 2018-01-01      2537274.0
# 2018-02-01      2683769.0
# 2018-03-01      2753557.0
# 2018-04-01      2710101.0
# 2018-05-01      2869783.0
# 2018-06-01      2743748.0
# 2018-07-01      2441045.0
# 2018-08-01      2622693.0
# 2018-09-01      2627334.0

# %%
plt.figure(figsize=(10,7))
sns.lineplot(data=spotify_data)

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,6))

# Add title
plt.title("Daily Global Streams of Popular Songs in 2017-2018")

# Line chart showing daily global streams of each song 
sns.lineplot(data=spotify_data)

# %%
list(spotify_data.columns)
# Out:
# ['Shape of You',
#  'Despacito',
#  'Something Just Like This',
#  'HUMBLE.',
#  'Unforgettable']

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,6))

# Add title
plt.title("Daily Global Streams of Popular Songs in 2017-2018")

# Line chart showing daily global streams of 'Shape of You'
sns.lineplot(data=spotify_data['Shape of You'], label="Shape of You")

# Line chart showing daily global streams of 'Despacito'
sns.lineplot(data=spotify_data['Despacito'], label="Despacito")

# Add label for horizontal axis
plt.xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')
